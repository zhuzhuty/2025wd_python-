# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 折线图绘制以及样式设置

# %%
'''
基础属性设置
color='red' : 折线的颜色
alpha=0.5 : 折线的透明度(0-1)
linestyle='--' : 折线的样式
linewidth=3 : 折线的宽度—粗细

线的样式
- 实线(solid)
-- 短线(dashed)
-. 短点相间线(dashdot)
： 虚点线(dotted)

折点的样式
o 实心圆
^ 实心三角
s 实心方块
* 星形
+ 加号
x x形
D 菱形
d 瘦菱形
h 六边形
H 大六边形
p 五边形
< 左三角
> 右三角
v 下三角
| 垂直线
_ 水平线
'''
x = range(1,8)
y=[17, 17, 18, 15, 11, 11, 13]
plt.plot(x,y,color='red',alpha=0.8,linestyle='-.',linewidth=3,marker='^')
plt.show()

# %% [markdown]
# ### 图片大小的设置

# %%
'''
figsize:指定figure的宽和高，单位为英寸；
dpi参数指定绘图对象的分辨率，即每英寸多少个像素，缺省值为80，1英寸等于2.5cm,A4纸是21*30cm的纸张
'''
import random
x = range(2,26,2)
y=[random.randint(15,30) for i in x]
plt.figure(figsize=(20,8),dpi=80) 
plt.plot(x,y)
#plt.show() # show会释放资源，所以在show之后的操作会无效
plt.savefig('test.png') # 也可以保存为svg格式的矢量图
plt.savefig('test.svg')

# %% [markdown]
# ### 设置x轴和y轴的刻度，以及标题

# %%
x = range(2,26,2)
y=[random.randint(15,30) for i in x]
plt.figure(figsize=(20,8),dpi=80)

# 设置x轴的刻度
# plt.xticks(x)
# plt.xticks(range(1,25))
# 设置y轴的刻度
# plt.yticks(y)
# plt.yticks(range(min(y),max(y)+1))

# 设置x轴的刻度
x_labels=['{}:00'.format(i) for i in x]
plt.xticks(x,x_labels,rotation=45) # rotation旋转刻度
# 设置y轴的刻度
y_labels=['{}℃'.format(i) for i in range(min(y),max(y)+1)]
plt.yticks(range(min(y),max(y)+1),y_labels)
plt.plot(x,y)

# 设置x轴和y轴的名称，以及标题
from matplotlib import font_manager
my_font=font_manager.FontProperties(fname='C:/Windows/Fonts/STXIHEI.TTF',size=18)
plt.xlabel('时间',fontproperties=my_font)
plt.ylabel('温度',fontproperties=my_font)
plt.title('温度变化图',fontproperties=my_font)
plt.show()

# %% [markdown]
# ### 一图多线

# %%
x = range(8,19)
y1=[131, 123, 122, 125, 126, 128, 129, 130, 127, 126, 125]
y2=[121, 113, 112, 115, 116, 118, 119, 120, 117, 116, 115]

plt.figure(figsize=(20,8),dpi=80)
plt.plot(x,y1,label='小明',color='red',linestyle='-.')
plt.plot(x,y2,label='小红',color='blue',linestyle='--')
plt.legend(prop=my_font) # 显示图例

# %% [markdown]
# ### 散点图

# %%
y = [11, 17, 16, 11, 12, 11, 12, 6, 6, 7, 8, 9, 12, 15, 14, 17,
     18, 21, 16, 17, 20, 14,15, 15, 15, 19, 21, 22, 22, 22,23]
x = range( 1, 32 )

plt.figure(figsize=(20,8),dpi=80)
plt.scatter(x,y,label='3月份')
x_labels=['3月{}日'.format(i) for i in x]
plt.xticks(x[::3],x_labels[::3],rotation=45,fontproperties=my_font)
y_labels=['{}℃'.format(i) for i in range(min(y),max(y)+1)]
plt.yticks(range(min(y),max(y)+1),y_labels,fontproperties=my_font)
plt.xlabel('日期',fontproperties=my_font)
plt.ylabel('温度',fontproperties=my_font)
plt.grid(alpha=0.5)
plt.show()

# %% [markdown]
# ### 条形图

# %%
a=['北京','上海','广州','深圳','成都']
b=[60000, 58000, 50000, 30000, 20000]
plt.figure(figsize=(20,8),dpi=80)
plt.bar(range(len(a)),b,width=0.3)
plt.xticks(range(len(a)),a,fontproperties=my_font)
# Out:
# ([<matplotlib.axis.XTick at 0x1cb61269810>,
# ...
#  [Text(0, 0, '北京'),
#   Text(1, 0, '上海'),
#   Text(2, 0, '广州'),
#   Text(3, 0, '深圳'),
#   Text(4, 0, '成都')])

# %% [markdown]
# ### 直方图

# %%
time = [131, 98, 125, 131, 124, 139, 131, 117, 128, 108, 135, 138, 131, 102,
107, 114,
119, 128, 121, 142, 127, 130, 124, 101, 110, 116, 117, 110, 128, 128, 115,
99,
136, 126, 134, 95, 138, 117, 111,78, 132, 124, 113, 150, 110, 117, 86,
95, 144,
105, 126, 130,126, 130, 126, 116, 123, 106, 112, 138, 123, 86, 101, 99, 136,123,
117, 119, 105, 137, 123, 128, 125, 104, 109, 134, 125, 127,105, 120, 107, 129,
116,
108, 132, 103, 136, 118, 102, 120, 114,105, 115, 132, 145, 119, 121, 112, 139,
125,
138, 109, 132, 134,156, 106, 117, 127, 144, 139, 139, 119, 140, 83, 110,
102,123,
107, 143, 115, 136, 118, 139, 123, 112, 118, 125, 109, 119, 133,112, 114, 122,
109,
106, 123, 116, 131, 127, 115, 118, 112, 135,115, 146, 137, 116, 103,
144, 83, 123,
111, 110, 111, 100, 154,136, 100, 118, 119, 133, 134, 106, 129, 126,
110, 111, 109,
141,120, 117, 106, 149, 122, 122, 110, 118, 127, 121, 114, 125, 126,114, 140, 103,
130, 141, 117, 106, 114, 121, 114, 133, 137, 92,121, 112, 146, 97, 137,
105, 98,
117, 112, 81, 97, 139, 113,134, 106, 144, 110, 137, 137, 111, 104, 117,
100, 111,
101, 110,105, 129, 137, 112, 120, 113, 133, 112, 83, 94, 146, 133,
101,131, 116,
111, 84, 137, 115, 122, 106, 144, 109, 123, 116, 111,111, 133, 150]
plt.figure(figsize=(20,8),dpi=80)

distance=2
group_num=(max(time)-min(time))//distance+1
plt.hist(time,group_num)
plt.xticks(range(min(time),max(time)+1,distance))

plt.grid(linestyle='--',alpha=0.5)
plt.xlabel('时间',fontproperties=my_font)
plt.ylabel('个数',fontproperties=my_font)
# Out:
# Text(0, 0.5, '个数')

# %% [markdown]
# ### 饼图

# %%
"""
绘 制 饼 图
explode： 设 置 各 部 分 突 出
label: 设 置 各 部 分 标 签
labeldistance:设置标签文本距圆心位置，1.1 表示 1.1 倍半径
autopct： 设 置 圆 里 面 文 本
shadow：设置是否有阴影
startangle：起始角度，默认从 0 开始逆时针转
pctdistance：设置圆内文本距圆心距离返回值
l_text：圆内部文本，
matplotlib.text.Text object
p_text：圆外部文本
"""
size=[10,55,35]
labels=['A','B','C']
color=['red','blue','green']
explode=[0.1,0,0] # 只突出A

plt.pie(size,explode=explode,labels=labels,colors=color,autopct='%1.1f%%',startangle=90,)
plt.legend()
plt.show()
